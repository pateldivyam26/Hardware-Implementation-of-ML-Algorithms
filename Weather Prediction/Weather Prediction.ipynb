# %% [markdown]
# ## EMBEDDED SYSTEMS COURSE PROJECT

# %% [markdown]
# ### Weather Prediction Using Arduino Nano BLE 33 Sensor

# %%
# Including header files
import pickle
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB,CategoricalNB
from pprint import pprint
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import ShuffleSplit
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Weather Data.csv")
df
# Out:
#         DateTime             Condition  Rain  MaxTemp  MinTemp   SunRise  \
# 0     02.09.2019         Partly cloudy  0.00       27       22  06:32:00
# 1     01.09.2019         Partly cloudy  0.00       27       22  06:31:00
# 2     31.08.2019  Patchy rain possible  0.50       26       22  06:30:00
# 3     30.08.2019         Partly cloudy  0.00       27       22  06:29:00
# 4     29.08.2019         Partly cloudy  0.00       27       23  06:27:00
# ...          ...                   ...   ...      ...      ...       ...
# 3891  05.01.2009              Overcast  4.32        5        3  08:29:00
# 3892  04.01.2009                  Mist  2.91        5        3  08:29:00
# 3893  03.01.2009              Overcast  0.08        5        3  08:29:00
# 3894  02.01.2009              Overcast  4.48        4        1  08:29:00
# 3895  01.01.2009         Partly cloudy  0.23        5        2  08:29:00
#
#         SunSet  MoonRise   MoonSet  AvgWind  AvgHumidity  AvgPressure
# 0     19:37:00   9:52:00  21:45:00       23           66         1012
# 1     19:38:00   8:37:00  21:13:00       21           66         1011
# 2     19:40:00   7:21:00  20:40:00       22           63         1015
# 3     19:42:00    6:4:00   20:5:00       20           64         1016
# 4     19:43:00   4:47:00  19:26:00       24           61         1015
# ...        ...       ...       ...      ...          ...          ...
# 3891  17:50:00   0:41:00   1:57:00       15           97         1015
# 3892  17:49:00   0:15:00  12:48:00        9           94         1014
# 3893  17:48:00  11:52:00       NaN       16           94         1021
# 3894  17:48:00  11:30:00  23:43:00       12           89         1021
# 3895  17:47:00   11:9:00  22:39:00       10           90         1027
#
# [3896 rows x 12 columns]

# %%
df = df[["MaxTemp","AvgPressure","AvgHumidity","Condition"]]
df
# Out:
#       MaxTemp  AvgPressure  AvgHumidity             Condition
# 0          27         1012           66         Partly cloudy
# 1          27         1011           66         Partly cloudy
# 2          26         1015           63  Patchy rain possible
# 3          27         1016           64         Partly cloudy
# 4          27         1015           61         Partly cloudy
# ...       ...          ...          ...                   ...
# 3891        5         1015           97              Overcast
# 3892        5         1014           94                  Mist
# 3893        5         1021           94              Overcast
# 3894        4         1021           89              Overcast
# 3895        5         1027           90         Partly cloudy
#
# [3896 rows x 4 columns]

# %%
df = df.dropna() #remove empty rows

#Convert each category into an integer
for ind in df.index:
  if df["Condition"][ind]=='Sunny':
    df["Condition"][ind] = 0
  elif df["Condition"][ind]=='Partly cloudy':
    df["Condition"][ind] = 1
  elif df["Condition"][ind]=='Cloudy':
    df["Condition"][ind] = 2
  elif df["Condition"][ind]=='Overcast':
    df["Condition"][ind] = 3
  elif df["Condition"][ind]=='Patchy rain possible':
    df["Condition"][ind] = 4
  
  else:
    df = df.drop([ind]) #we don't consider other classes so we drop it

#Cast this column to int
df["Condition"] = df["Condition"].astype(int)

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, shuffle=True, random_state = 42)

# %% [markdown]
# #### Training XGBoost Classifier

# %%
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

xgb_model = XGBClassifier()
xgb_model.fit(X_train, y_train)
pred = xgb_model.predict(X_test)
print(accuracy_score(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# 0.6049601417183348
#               precision    recall  f1-score   support
#
#            0       0.71      0.85      0.77       668
#            1       0.35      0.24      0.29       238
#            2       0.04      0.01      0.02        91
#            3       0.44      0.50      0.47       114
#            4       0.25      0.06      0.09        18
#
#     accuracy                           0.60      1129
#    macro avg       0.36      0.33      0.33      1129
# weighted avg       0.54      0.60      0.57      1129

# %% [markdown]
# #### Training LGBM Classifier

# %%
lgb_model = LGBMClassifier()
lgb_model.fit(X_train, y_train)
pred = lgb_model.predict(X_test)
print(accuracy_score(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# 0.6102745792736936
#               precision    recall  f1-score   support
#
#            0       0.71      0.85      0.78       668
#            1       0.37      0.24      0.29       238
#            2       0.10      0.03      0.05        91
#            3       0.43      0.51      0.47       114
#            4       0.11      0.06      0.07        18
#
#     accuracy                           0.61      1129
#    macro avg       0.34      0.34      0.33      1129
# weighted avg       0.55      0.61      0.57      1129

# %% [markdown]
# #### Training Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier 
rgc_model = RandomForestClassifier()
rgc_model.fit(X_train, y_train)
pred = rgc_model.predict(X_test)
print(accuracy_score(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# 0.5907883082373782
#               precision    recall  f1-score   support
#
#            0       0.72      0.82      0.77       668
#            1       0.29      0.25      0.27       238
#            2       0.10      0.04      0.06        91
#            3       0.44      0.46      0.45       114
#            4       0.20      0.06      0.09        18
#
#     accuracy                           0.59      1129
#    macro avg       0.35      0.33      0.33      1129
# weighted avg       0.54      0.59      0.56      1129

# %% [markdown]
# #### Training Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, y_train)
pred = gnb.predict(X_test)
print(accuracy_score(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# 0.6288751107174491
#               precision    recall  f1-score   support
#
#            0       0.72      0.91      0.80       668
#            1       0.40      0.07      0.12       238
#            2       0.17      0.02      0.04        91
#            3       0.36      0.72      0.48       114
#            4       0.00      0.00      0.00        18
#
#     accuracy                           0.63      1129
#    macro avg       0.33      0.34      0.29      1129
# weighted avg       0.56      0.63      0.55      1129

# %% [markdown]
# #### Training Logistic Regression

# %%
from sklearn.linear_model import  LogisticRegression
lr = LogisticRegression()
lr.fit(X_train, y_train)
pred = lr.predict(X_test)
print(accuracy_score(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# 0.6377325066430469
#               precision    recall  f1-score   support
#
#            0       0.68      0.97      0.80       668
#            1       0.00      0.00      0.00       238
#            2       0.00      0.00      0.00        91
#            3       0.42      0.64      0.51       114
#            4       0.00      0.00      0.00        18
#
#     accuracy                           0.64      1129
#    macro avg       0.22      0.32      0.26      1129
# weighted avg       0.44      0.64      0.52      1129

# %%
import tensorflow as tf

# %%
from keras.utils import to_categorical

y_train_oh = to_categorical(y_train) #Create classes from the labels
y_test_oh = to_categorical(y_test)
# y_train_oh

# %%
#Parameters :
NB_classes = 5 #number of outputs
NB_neurones = 30 #main number of neurones
NB_features = 3 #number of inputs
activation_func = tf.keras.activations.relu #activation function used

#Densly connected neural network
model = tf.keras.Sequential([
                             tf.keras.layers.Dense(NB_neurones,activation=activation_func,input_shape=(NB_features,)),
                             tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                             tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                             tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                             tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                             tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                             tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                             tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                             tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                             tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                             tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                             tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                             tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                             tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                             tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                             tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                             tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                             tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                             tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                             tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                             tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                             tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                             tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                             tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                             tf.keras.layers.Dense(NB_neurones,activation=activation_func),
                             tf.keras.layers.Dropout(0.4), #drop randomly some connection to avoid overfiting
                             #softmax will output an array containing probabilities of each classes
                             #the highest one is the predicted class
                             tf.keras.layers.Dense(NB_classes,activation=tf.keras.activations.softmax)
])

model.compile(optimizer="adam",loss=tf.keras.losses.categorical_crossentropy, metrics=['accuracy']) #compile the model

model.summary() #to see the paramter of our model
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_78 (Dense)            (None, 30)                120
#
#  dense_79 (Dense)            (None, 30)                930
#
#  dense_80 (Dense)            (None, 30)                930
#
#  dense_81 (Dense)            (None, 30)                930
#
#  dense_82 (Dense)            (None, 30)                930
#
#  dense_83 (Dense)            (None, 30)                930
#
#  dense_84 (Dense)            (None, 30)                930
#
#  dense_85 (Dense)            (None, 30)                930
#
#  dense_86 (Dense)            (None, 30)                930
#
#  dense_87 (Dense)            (None, 30)                930
#
#  dense_88 (Dense)            (None, 30)                930
#
#  dense_89 (Dense)            (None, 30)                930
#
#  dense_90 (Dense)            (None, 30)                930
#
#  dense_91 (Dense)            (None, 30)                930
#
#  dense_92 (Dense)            (None, 30)                930
#
#  dense_93 (Dense)            (None, 30)                930
#
#  dense_94 (Dense)            (None, 30)                930
#
#  dense_95 (Dense)            (None, 30)                930
#
#  dense_96 (Dense)            (None, 30)                930
#
#  dense_97 (Dense)            (None, 30)                930
#
#  dense_98 (Dense)            (None, 30)                930
#
#  dense_99 (Dense)            (None, 30)                930
#
#  dense_100 (Dense)           (None, 30)                930
#
#  dense_101 (Dense)           (None, 30)                930
#
#  dense_102 (Dense)           (None, 30)                930
#
#  dropout_3 (Dropout)         (None, 30)                0
#
#  dense_103 (Dense)           (None, 5)                 155
#
# =================================================================
# Total params: 22,595
# Trainable params: 22,595
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x=X_train,
          y=y_train_oh,
          epochs=50,
          validation_data=(X_test, y_test_oh),
          verbose=1,
          shuffle=True)  # Train our model
# Out:
# Epoch 1/50
# 83/83 [==============================] - 1s 8ms/step - loss: 0.9951 - accuracy: 0.6388 - val_loss: 0.9623 - val_accuracy: 0.6368
# Epoch 2/50
# 83/83 [==============================] - 1s 9ms/step - loss: 0.9504 - accuracy: 0.6468 - val_loss: 0.9606 - val_accuracy: 0.6306
# Epoch 3/50
# 83/83 [==============================] - 1s 7ms/step - loss: 0.9380 - accuracy: 0.6426 - val_loss: 0.9702 - val_accuracy: 0.6236
# Epoch 4/50
# 83/83 [==============================] - 1s 6ms/step - loss: 0.9570 - accuracy: 0.6529 - val_loss: 0.9937 - val_accuracy: 0.6165
# Epoch 5/50
# 83/83 [==============================] - 1s 6ms/step - loss: 0.9537 - accuracy: 0.6487 - val_loss: 0.9728 - val_accuracy: 0.6306
# Epoch 6/50
# 83/83 [==============================] - 1s 6ms/step - loss: 0.9410 - accuracy: 0.6540 - val_loss: 0.9542 - val_accuracy: 0.6227
# Epoch 7/50
# 83/83 [==============================] - 0s 6ms/step - loss: 0.9479 - accuracy: 0.6472 - val_loss: 0.9485 - val_accuracy: 0.6298
# Epoch 8/50
# 83/83 [==============================] - 1s 6ms/step - loss: 0.9604 - accuracy: 0.6449 - val_loss: 0.9710 - val_accuracy: 0.6209
# Epoch 9/50
# 83/83 [==============================] - 1s 6ms/step - loss: 0.9661 - accuracy: 0.6438 - val_loss: 0.9538 - val_accuracy: 0.6244
# Epoch 10/50
# 83/83 [==============================] - 1s 6ms/step - loss: 0.9404 - accuracy: 0.6513 - val_loss: 0.9628 - val_accuracy: 0.6360
# Epoch 11/50
# 83/83 [==============================] - 1s 7ms/step - loss: 0.9390 - accuracy: 0.6506 - val_loss: 1.0015 - val_accuracy: 0.6085
# Epoch 12/50
# 83/83 [==============================] - 1s 7ms/step - loss: 0.9596 - accuracy: 0.6468 - val_loss: 0.9638 - val_accuracy: 0.6360
# Epoch 13/50
# 83/83 [==============================] - 0s 6ms/step - loss: 0.9466 - accuracy: 0.6472 - val_loss: 0.9589 - val_accuracy: 0.6342
# Epoch 14/50
# 83/83 [==============================] - 1s 6ms/step - loss: 0.9412 - accuracy: 0.6491 - val_loss: 0.9575 - val_accuracy: 0.6236
# Epoch 15/50
# 83/83 [==============================] - 1s 7ms/step - loss: 0.9561 - accuracy: 0.6407 - val_loss: 0.9569 - val_accuracy: 0.6333
# Epoch 16/50
# 83/83 [==============================] - 0s 6ms/step - loss: 0.9326 - accuracy: 0.6567 - val_loss: 0.9569 - val_accuracy: 0.6244
# Epoch 17/50
# 83/83 [==============================] - 1s 6ms/step - loss: 0.9400 - accuracy: 0.6476 - val_loss: 0.9624 - val_accuracy: 0.6280
# Epoch 18/50
# 83/83 [==============================] - 1s 6ms/step - loss: 0.9616 - accuracy: 0.6392 - val_loss: 0.9747 - val_accuracy: 0.6395
# Epoch 19/50
# 83/83 [==============================] - 1s 6ms/step - loss: 0.9347 - accuracy: 0.6476 - val_loss: 0.9746 - val_accuracy: 0.6368
# Epoch 20/50
# 83/83 [==============================] - 1s 6ms/step - loss: 0.9351 - accuracy: 0.6502 - val_loss: 0.9486 - val_accuracy: 0.6289
# Epoch 21/50
# 83/83 [==============================] - 1s 8ms/step - loss: 0.9340 - accuracy: 0.6525 - val_loss: 0.9530 - val_accuracy: 0.6377
# Epoch 22/50
# 83/83 [==============================] - 0s 6ms/step - loss: 0.9402 - accuracy: 0.6529 - val_loss: 0.9664 - val_accuracy: 0.6360
# Epoch 23/50
# 83/83 [==============================] - 1s 6ms/step - loss: 0.9273 - accuracy: 0.6521 - val_loss: 0.9574 - val_accuracy: 0.6227
# Epoch 24/50
# 83/83 [==============================] - 0s 6ms/step - loss: 0.9351 - accuracy: 0.6521 - val_loss: 0.9593 - val_accuracy: 0.6209
# Epoch 25/50
# 83/83 [==============================] - 1s 6ms/step - loss: 0.9346 - accuracy: 0.6483 - val_loss: 0.9743 - val_accuracy: 0.6351
# Epoch 26/50
# 83/83 [==============================] - 1s 6ms/step - loss: 0.9528 - accuracy: 0.6445 - val_loss: 1.0056 - val_accuracy: 0.6120
# Epoch 27/50
# 83/83 [==============================] - 0s 5ms/step - loss: 0.9413 - accuracy: 0.6457 - val_loss: 0.9478 - val_accuracy: 0.6280
# Epoch 28/50
# 83/83 [==============================] - 0s 5ms/step - loss: 0.9333 - accuracy: 0.6502 - val_loss: 0.9504 - val_accuracy: 0.6315
# Epoch 29/50
# 83/83 [==============================] - 0s 5ms/step - loss: 0.9321 - accuracy: 0.6544 - val_loss: 0.9733 - val_accuracy: 0.6244
# Epoch 30/50
# 83/83 [==============================] - 0s 6ms/step - loss: 0.9297 - accuracy: 0.6563 - val_loss: 0.9821 - val_accuracy: 0.6351
# Epoch 31/50
# 83/83 [==============================] - 0s 5ms/step - loss: 0.9516 - accuracy: 0.6476 - val_loss: 0.9674 - val_accuracy: 0.6244
# Epoch 32/50
# 83/83 [==============================] - 0s 5ms/step - loss: 0.9360 - accuracy: 0.6483 - val_loss: 0.9503 - val_accuracy: 0.6244
# Epoch 33/50
# 83/83 [==============================] - 0s 5ms/step - loss: 0.9380 - accuracy: 0.6487 - val_loss: 0.9535 - val_accuracy: 0.6368
# Epoch 34/50
# 83/83 [==============================] - 1s 7ms/step - loss: 0.9311 - accuracy: 0.6529 - val_loss: 0.9601 - val_accuracy: 0.6236
# Epoch 35/50
# 83/83 [==============================] - 0s 6ms/step - loss: 0.9247 - accuracy: 0.6525 - val_loss: 0.9484 - val_accuracy: 0.6377
# Epoch 36/50
# 83/83 [==============================] - 0s 5ms/step - loss: 0.9444 - accuracy: 0.6430 - val_loss: 0.9723 - val_accuracy: 0.6289
# Epoch 37/50
# 83/83 [==============================] - 0s 5ms/step - loss: 0.9327 - accuracy: 0.6460 - val_loss: 0.9485 - val_accuracy: 0.6280
# Epoch 38/50
# 83/83 [==============================] - 0s 5ms/step - loss: 0.9377 - accuracy: 0.6506 - val_loss: 0.9609 - val_accuracy: 0.6209
# Epoch 39/50
# 83/83 [==============================] - 0s 5ms/step - loss: 0.9365 - accuracy: 0.6521 - val_loss: 0.9654 - val_accuracy: 0.6289
# Epoch 40/50
# 83/83 [==============================] - 0s 5ms/step - loss: 0.9324 - accuracy: 0.6510 - val_loss: 0.9481 - val_accuracy: 0.6360
# Epoch 41/50
# 83/83 [==============================] - 0s 5ms/step - loss: 0.9270 - accuracy: 0.6502 - val_loss: 0.9471 - val_accuracy: 0.6298
# Epoch 42/50
# 83/83 [==============================] - 0s 5ms/step - loss: 0.9424 - accuracy: 0.6468 - val_loss: 0.9609 - val_accuracy: 0.6244
# Epoch 43/50
# 83/83 [==============================] - 0s 5ms/step - loss: 0.9396 - accuracy: 0.6506 - val_loss: 0.9591 - val_accuracy: 0.6368
# Epoch 44/50
# 83/83 [==============================] - 0s 5ms/step - loss: 0.9373 - accuracy: 0.6494 - val_loss: 0.9524 - val_accuracy: 0.6298
# Epoch 45/50
# 83/83 [==============================] - 0s 5ms/step - loss: 0.9387 - accuracy: 0.6491 - val_loss: 0.9572 - val_accuracy: 0.6209
# Epoch 46/50
# 83/83 [==============================] - 0s 5ms/step - loss: 0.9295 - accuracy: 0.6521 - val_loss: 0.9767 - val_accuracy: 0.6236
# Epoch 47/50
# 83/83 [==============================] - 0s 6ms/step - loss: 0.9340 - accuracy: 0.6468 - val_loss: 0.9647 - val_accuracy: 0.6209
# Epoch 48/50
# 83/83 [==============================] - 0s 5ms/step - loss: 0.9380 - accuracy: 0.6483 - val_loss: 0.9634 - val_accuracy: 0.6244
# Epoch 49/50
# 83/83 [==============================] - 0s 5ms/step - loss: 0.9355 - accuracy: 0.6529 - val_loss: 0.9517 - val_accuracy: 0.6227
# Epoch 50/50
# 83/83 [==============================] - 0s 5ms/step - loss: 0.9320 - accuracy: 0.6491 - val_loss: 0.9443 - val_accuracy: 0.6377

# %%
performance=model.evaluate(X_test,y_test_oh, batch_size=32, verbose=1, steps=None, )[1] * 100
print('Final accuracy : ', round(performance), '%')
# Out:
# 36/36 [==============================] - 0s 3ms/step - loss: 0.9443 - accuracy: 0.6377
# Final accuracy :  64 %

# %%
import pickle

model_bytes = pickle.dumps(model)
with open('model.h', 'w') as f:
    f.write('#ifndef MODEL_H\n')
    f.write('#define MODEL_H\n')
    f.write('#include <stdint.h>\n')
    f.write('const uint8_t model_data[] = {')
    for byte in model_bytes:
        f.write(str(hex(byte)) + ', ')
    f.write('};\n')
    f.write('#endif\n')
# Out:
# INFO:tensorflow:Assets written to: ram://71c342ce-6a86-410e-92e5-be240cc43e8f/assets
